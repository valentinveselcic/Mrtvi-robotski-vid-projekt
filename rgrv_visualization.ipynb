# %%
# Simple Z-value filtering to remove the plane
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from rgrv_project_helper_functions import PNGPointCloudDataset, png_to_pointcloud

# %matplotlib inline

# Camera parameters
image_width = 640
image_height = 480
fx = fy = 525.0
cx = image_width / 2 - 0.5
cy = image_height / 2 - 0.5

# Load original point cloud
points_original = png_to_pointcloud('miniBRANCH\\tree_1_V_0001\\Filtered__noGrass\\depth\\0.png', 
                                   fx=fx, fy=fy, cx=cx, cy=cy)

# Filter points with Z <= 0.2
z_threshold = 0.2
mask = points_original[:, 2] <= z_threshold
points_filtered = points_original[mask]

# Visualize comparison
fig = plt.figure(figsize=(15, 6))

# Original point cloud
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(points_original[:, 0], points_original[:, 1], points_original[:, 2], 
           s=0.5, c=points_original[:, 2], cmap='viridis', alpha=0.6)
ax1.set_title('Original Point Cloud')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Filtered point cloud
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(points_filtered[:, 0], points_filtered[:, 1], points_filtered[:, 2], 
           s=0.5, c=points_filtered[:, 2], cmap='viridis', alpha=0.6)
ax2.set_title(f'Filtered Point Cloud (Z ≤ {z_threshold})')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.tight_layout()
plt.show()

print(f"Original points: {len(points_original)}")
print(f"Filtered points: {len(points_filtered)}")
print(f"Removed: {len(points_original) - len(points_filtered)} points")
print(f"Z range - Original: [{points_original[:, 2].min():.3f}, {points_original[:, 2].max():.3f}]")
print(f"Z range - Filtered: [{points_filtered[:, 2].min():.3f}, {points_filtered[:, 2].max():.3f}]")
# Out:
# Original points: 8192
# Filtered points: 8192
# Removed: 0 points
# Z range - Original: [0.001, 0.118]
# Z range - Filtered: [0.001, 0.118]

# %%
# Simple Z-value filtering to remove the plane
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from rgrv_project_helper_functions import PNGPointCloudDataset, png_to_pointcloud

# %matplotlib inline

# Camera parameters
image_width = 640
image_height = 480
fx = fy = 525.0
cx = image_width / 2 - 0.5
cy = image_height / 2 - 0.5

# Load original point cloud
points_original = png_to_pointcloud('miniBRANCH\\tree_1_V_0001\\Filtered__noGrass\\depth\\0.png', 
                                   fx=fx, fy=fy, cx=cx, cy=cy)

# Filter points with Z <= 0.2
z_threshold = 0.2
mask = points_original[:, 2] <= z_threshold
points_filtered = points_original[mask]

# Visualize comparison
fig = plt.figure(figsize=(15, 6))

# Original point cloud
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(points_original[:, 0], points_original[:, 1], points_original[:, 2], 
           s=0.5, c=points_original[:, 2], cmap='viridis', alpha=0.6)
ax1.set_title('Original Point Cloud')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Filtered point cloud
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(points_filtered[:, 0], points_filtered[:, 1], points_filtered[:, 2], 
           s=0.5, c=points_filtered[:, 2], cmap='viridis', alpha=0.6)
ax2.set_title(f'Filtered Point Cloud (Z ≤ {z_threshold})')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.tight_layout()
plt.show()

print(f"Original points: {len(points_original)}")
print(f"Filtered points: {len(points_filtered)}")
print(f"Removed: {len(points_original) - len(points_filtered)} points")
print(f"Z range - Original: [{points_original[:, 2].min():.3f}, {points_original[:, 2].max():.3f}]")
print(f"Z range - Filtered: [{points_filtered[:, 2].min():.3f}, {points_filtered[:, 2].max():.3f}]")

# %%
# Simple Z-value filtering to remove the plane
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from rgrv_project_helper_functions import PNGPointCloudDataset, png_to_pointcloud

# %matplotlib inline

# Camera parameters
image_width = 640
image_height = 480
fx = fy = 525.0
cx = image_width / 2 - 0.5
cy = image_height / 2 - 0.5

# Load original point cloud
points_original = png_to_pointcloud('miniBRANCH\\tree_1_V_0001\\Filtered__noGrass\\depth\\0.png', 
                                   fx=fx, fy=fy, cx=cx, cy=cy)

# Filter points with Z <= 0.2
z_threshold = 0.2
mask = points_original[:, 2] <= z_threshold
points_filtered = points_original[mask]

# Visualize comparison
fig = plt.figure(figsize=(15, 6))

# Original point cloud
ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter(points_original[:, 0], points_original[:, 1], points_original[:, 2], 
           s=0.5, c=points_original[:, 2], cmap='viridis', alpha=0.6)
ax1.set_title('Original Point Cloud')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Filtered point cloud
ax2 = fig.add_subplot(122, projection='3d')
ax2.scatter(points_filtered[:, 0], points_filtered[:, 1], points_filtered[:, 2], 
           s=0.5, c=points_filtered[:, 2], cmap='viridis', alpha=0.6)
ax2.set_title(f'Filtered Point Cloud (Z ≤ {z_threshold})')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.tight_layout()
plt.show()

print(f"Original points: {len(points_original)}")
print(f"Filtered points: {len(points_filtered)}")
print(f"Removed: {len(points_original) - len(points_filtered)} points")
print(f"Z range - Original: [{points_original[:, 2].min():.3f}, {points_original[:, 2].max():.3f}]")
print(f"Z range - Filtered: [{points_filtered[:, 2].min():.3f}, {points_filtered[:, 2].max():.3f}]")
# Out:
# Original points: 8192
# Filtered points: 560
# Removed: 7632 points
# Z range - Original: [0.002, 0.254]
# Z range - Filtered: [0.002, 0.117]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from rgrv_project_helper_functions import PNGPointCloudDataset, png_to_pointcloud

# %matplotlib inline

# Example for a 640x480 image
image_width = 640
image_height = 480

fx = fy = 525.0  # Typical value for depth cameras, in pixels
cx = image_width / 2 - 0.5
cy = image_height / 2 - 0.5

# Method 1: Use the png_to_pointcloud function directly
points = png_to_pointcloud('miniBRANCH\\tree_1_V_0001\\Filtered__noGrass\\depth\\0.png', 
                          fx=fx, fy=fy, cx=cx, cy=cy)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], s=0.5, c=points[:, 2], cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('3D Point Cloud from Single Image')
plt.show()

print(f"Point cloud shape: {points.shape}")
print(f"Number of points: {len(points)}")
# Out:
# Point cloud shape: (8192, 3)
# Number of points: 8192

# %%
import cv2
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# Load image
img = cv2.imread('miniBRANCH\\tree_1_V_0001\\Filtered__noGrass\\depth\\0.png', cv2.IMREAD_UNCHANGED)  # Preserves depth

print(f"Shape: {img.shape}")
print(f"Data type: {img.dtype}")
print(f"Min: {img.min()}, Max: {img.max()}")

# Show image
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.title('Depth Image')
plt.show()
# Out:
# Shape: (640, 480)
# Data type: uint8
# Min: 0, Max: 254
